# %%
a = "Hii , how are you ?"
b = 98

# %%
+ ,-,/,//,%,*
==,>=,<=
true false

# %%
x = 2

# %%
if x == 2:
    print("yess")
elif x != 2:
    print("mid")
else :
    print ("noo")
# Out:
# mid

# %%
for loop (until the condition is fifilled )
while loop (until the condition is not fifilled )

# %%
try :

    pass
else:
    pass

# %%
r
w,
o

# %%
 a = [ x in x fro nums if 10 + 2 ]
